# %%
s = "Instagram"
print(len(s))
char1=s[-4]
char2=s[-3]
char3=s[-2]
char4=s[-1]

print(char1,char2,char3,char4)
# Out:
# 9
# g r a m

# %%
s1 = "Python Programming"
print(len(s1))
ch1=s1[-18]
ch2=s1[-1]
print(ch1,ch2)
# Out:
# 18
# P g

# %%
ch3=s1[0]
ch4=s1[17]
print(ch3,ch4)
# Out:
# P g

# %%
ch5=s1[-18]
ch6=s1[-1]
print(ch5,ch6)
# Out:
# P g

# %%
print(s1[0], s1[-1])
print(s1[-18], s1[17])
print(s1[0], s1[17])
print(s1[-18], s1[-1])
# Out:
# P g
# P g
# P g
# P g
