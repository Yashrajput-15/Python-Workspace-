# %%
a = 50
print(a)
print(type(a))
# Out:
# 50
# <class 'int'>

# %%
price_petrol = 111.50
print(price_petrol)
print(type(price_petrol))
# Out:
# 111.5
# <class 'float'>

# %%
a = 55
b = 10.55
print(a+b)
print(type(a))
print(type(b))
# Out:
# 65.55
# <class 'int'>
# <class 'float'>

# %%
is_present = True
is_logged_in = False

# %%
var = 'A'
print (var)
print(type(var))
# Out:
# A
# <class 'str'>

# %%
name = input("Enter Your Name")
print('Hello',(name))
# Out:
# Hello Yash

# %%
num = input('Enter Any Number')
print(num)
print(type(num))
print(id(num))
# Out:
# 11
# <class 'str'>
# 1949828646112

# %%
num1 = int(input("Enter Any Number"))
print(num1)
print(type(num1))
# Out:
# 55
# <class 'int'>

# %%
val1 = int(input("Enter Val1"))
val2 = int(input("ENter Val2"))
print(val1+val2)
# Out:
# 22

# %%
val1 = int(input("Enter Val1"))
val2 = float(input("ENter Val2"))
print(val1+val2)
# Out:
# 31.2

# %%
val1 = int(input("Enter Val1"))
val2 = float(input("ENter Val2"))
val3 = complex(input("Enter val3"))
print(val1+val2+val3)
# Out:
# (22.2+12j)
